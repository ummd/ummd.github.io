# %% [markdown]
# # Lecture 3c
#
# ## Test Statistics
#
# This example will demonstrate the variance of the least squares estimator
#
# $$Y=\beta_0 + \beta_1 X + \epsilon$$

# %% [markdown]
# ## The Statistical Properties of test statistic under the NULL hypothesis
#
# This example will demonstrate the distribution of the test statistic under the null hypothesis $\beta_0=0$, $\beta_1=0$
#
# i.e. what would the estimates look like if the null were true?

# %%
S <- 1000 #number of samples
n <- 100 #number of observations per sample

b0 <- 0
b1 <- 0

e <- replicate(S,rnorm(n)) #draw S samples

x <- 1:n

y <- b0 + b1*x + e

bh=matrix(,2,S) #initialize matrix to store estimates of beta
seh=matrix(,2,S) #initialize matrix to store estimates of beta

for (s in 1:S){
    lm.fit=lm(y[,s]~x) # estimate the linear model on the sample s.
    bh[1:2,s] <- coef(lm.fit)   #store the estimates    
    seh[1:2,s] <- sqrt(diag(vcov(lm.fit)))   #store the standard errorsfit = lm(ydata ~ .,data = data)  
}

t0=bh[1,]/seh[1,]
t1=bh[2,]/seh[2,]

# %% [markdown]
# Notice that each test statistic is different. This is due to the randomness in each of the training samples. We can see this in histograms for $t_0$ amd $t_1$.

# %%
hist(t0)
# Out:
# Plot with title “Histogram of t0”

# %%
hist(t1)
# Out:
# Plot with title “Histogram of t1”

# %% [markdown]
# ## The Statistical Properties of test statistic under the ALTERNATIVE hypothesis
#
# This example will demonstrate the distribution of the test statistic under an alterantive hypothesis $\beta_0=0$, $\beta_1=0.15$
#
# i.e., what would the estimates look like if the alternative were true?

# %%
S <- 1000 #number of samples
n <- 100 #number of observations per sample

b0 <- 0
b1 <- .015

e <- replicate(S,rnorm(n)) #draw S samples

x <- 1:n

y <- b0 + b1*x + e

t0_alt=matrix(,1,S) #initialize matrix to store tstat for beta_1
t1_alt=matrix(,1,S) #initialize matrix to store tstat for beta_2

for (s in 1:S){
    lm.fit=lm(y[,s]~x) # estimate the linear model on the sample s.
    t0_alt[,s] <- summary(lm.fit)$coefficients[1,3]   #store the tstat for beta_0  
    t1_alt[,s] <- summary(lm.fit)$coefficients[2,3]   #store the tstats for beta_1
}

# %%
summary(lm.fit)
# Out:
# Call:
# lm(formula = y[, s] ~ x)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1343 -0.5887  0.0210  0.5200  2.2660
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.021314   0.184056   0.116    0.908
# x           0.013315   0.003164   4.208 5.71e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9134 on 98 degrees of freedom
# Multiple R-squared:  0.153,	Adjusted R-squared:  0.1444
# F-statistic: 17.71 on 1 and 98 DF,  p-value: 5.711e-05

# %%
hist(t1_alt)
# Out:
# Plot with title “Histogram of t1_alt”

# %% [markdown]
# Notice how this distribution is shifted far to the right? **When the alternative is true**, you should expect the test statistic from any given sample to lie above 1.96.

# %%
2*(1-pt(abs(t1_alt),98)) #calculate the pvalues for the test statisics under the null hypothesis, when the alternative is true
# Out:
#      [,1]         [,2]         [,3]       [,4]         [,5]
# [1,] 4.121696e-05 0.0001505559 0.00055181 0.0009679435 3.110125e-05
#      [,6]         [,7]         [,8]         [,9]         [,10]        [,11]
# [1,] 4.826834e-06 0.0001064106 3.367721e-08 1.719394e-05 8.466174e-05 ⋯
#      [,12]        [,13]        [,14]        [,15]        [,16]
# [1,] 5.089999e-05 1.646223e-06 3.344397e-05 2.986943e-05 0.0003357411
#      [,17]        [,18]        [,19]        [,20]        [,21]
# [1,] 5.449589e-07 1.222382e-05 2.552931e-06 0.0001071015 5.711258e-05

# %%
NOtice that these p-values are all very small? Under the null hypothesis, it is extremely unlikely that we would have obvserved the test statistic.

How confidant can we be? We pick a level, say 0.05, that we are willing to make a mistake. 

This is why you can **reject the null** of $\beta_1=0$ in favour of the alternative at the 0.05 level.
