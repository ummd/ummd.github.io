# %% [markdown]
# # Lecture 3e
# ## A Simple Time-Series Regression

# %%
set.seed(1) #set random seed so that the simulation is reproducible

n <- 100 #number of observations in sample

b0 <- 2
b1 <- .8

e <- rnorm(n) #draw sample of errors

y<-rep(0, n) #initialize y-vector, in particular y[1] is 0


for (t in 2:n){
    y[t] <- b0+ b1*y[t-1]+ e[t]  #generate the time-series
}

plot(y,type="l")
# Out:
# plot without title

# %% [markdown]
# When $\beta_1<0$ this process limits.
#
# When $\beta_1=1$ this process is called a random walk.
#
# When $\beta_1>1$ this process is amplified.
#
# Try changing $\beta_1$ above and see how the process changes.

# %%
#Estimate the model with a Lagged Dependent Variable
lm.fit=lm(y[2:n]~y[1:n-1]) #fit the linear model
summary(lm.fit) #display
# Out:
# Call:
# lm(formula = y[2:n] ~ y[1:n - 1])
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.31559 -0.62267  0.02883  0.59819  2.30888
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.61567    0.45687   5.725 1.15e-07 ***
# y[1:n - 1]   0.75071    0.04421  16.981  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.8986 on 97 degrees of freedom
# Multiple R-squared:  0.7483,	Adjusted R-squared:  0.7457
# F-statistic: 288.4 on 1 and 97 DF,  p-value: < 2.2e-16

# %% [markdown]
# Note that a linear regression is only appropriate when $\beta_1 <1$.

# %% [markdown]
# Using the dynlm package

# %%
library("dynlm")

    dfm.fit <- dynlm(y ~ L(y, 1))
    summary(dfm.fit)


    dfm.fit <- dynlm(y ~ L(y, 1) + L(uk, 2))
    summary(dfm.fit)
