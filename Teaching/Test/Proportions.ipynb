# %% [markdown]
# # Variance of Proportion

# %%
set.seed(1) #set random seed so that the simulation is reproducible

n <- 100 #number of observations per sample

p <-.12


y <- replicate(1000,rbinom(n,1,p)) #draw S samples 

var(colMeans(y))

p*(1-p)/n

hist(colMeans(y))
# Out:
# [1] 0.001068292
# [1] 0.001056
# Plot with title “Histogram of colMeans(y)”
